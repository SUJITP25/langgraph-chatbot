# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict, Annotated
from langchain_core.messages import BaseMessage, HumanMessage
from dotenv import load_dotenv

llm=""

# %%
from langgraph.graph.message import add_messages


class ChatState(TypedDict):
    messages: Annotated[list[BaseMessage], add_messages]


def chat_node(state: ChatState):
    message = state["messages"]
    response = llm.invoke(message)


graph = StateGraph(ChatState)
graph.add_node("chat_node", chat_node)
graph.add_edge(START,"chat_node")
graph.add_edge("chat_node",END)

graph.compile()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 16
#      13 graph = StateGraph(ChatState)
#      14 graph.add_node("chat_node", chat_node)
# ---> 16 graph.compile()
#
# File f:\python\Lib\site-packages\langgraph\graph\state.py:1113, in StateGraph.compile(self, checkpointer, cache, store, interrupt_before, interrupt_after, debug, name)
#    1110 interrupt_after = interrupt_after or []
#    1112 # validate the graph
# -> 1113 self.validate(
#    1114     interrupt=(
#    1115         (interrupt_before if interrupt_before != "*" else []) + interrupt_after
#    1116         if interrupt_after != "*"
#    1117         else []
#    1118     )
#    1119 )
#    1121 # prepare output channels
#    1122 output_channels = (
#    1123     "__root__"
#    1124     if len(self.schemas[self.output_schema]) == 1
#    (...)   1130     ]
#    1131 )
#
# File f:\python\Lib\site-packages\langgraph\graph\state.py:1003, in StateGraph.validate(self, interrupt)
#    1000         raise ValueError(f"Found edge starting at unknown node '{source}'")
#    1002 if START not in all_sources:
# -> 1003     raise ValueError(
#    1004         "Graph must have an entrypoint: add at least one edge from START to another node"
#    1005     )
#    1007 # assemble targets
#    1008 all_targets = {end for _, end in self._all_edges}
#
# ValueError: Graph must have an entrypoint: add at least one edge from START to another node
